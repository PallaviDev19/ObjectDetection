# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\9415\anaconda3\lib\site-packages (4.5.3.56)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\9415\anaconda3\lib\site-packages (from opencv-python) (1.19.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
pip install opencv-python tensorflow
# Out:
# Requirement already satisfied: opencv-python in c:\users\9415\anaconda3\lib\site-packages (4.5.3.56)
# Collecting tensorflow
#   Downloading tensorflow-2.5.0-cp38-cp38-win_amd64.whl (422.6 MB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\9415\anaconda3\lib\site-packages (from opencv-python) (1.19.2)
# Requirement already satisfied: wheel~=0.35 in c:\users\9415\anaconda3\lib\site-packages (from tensorflow) (0.35.1)
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting tensorboard~=2.5
#   Downloading tensorboard-2.5.0-py3-none-any.whl (6.0 MB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.17.3-cp38-cp38-win_amd64.whl (909 kB)
# Collecting h5py~=3.1.0
#   Downloading h5py-3.1.0-cp38-cp38-win_amd64.whl (2.7 MB)
# Collecting keras-nightly~=2.5.0.dev
#   Downloading keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
# Collecting flatbuffers~=1.12.0
# Note: you may need to restart the kernel to use updated packages.  Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Downloading tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting absl-py~=0.10
#   Downloading absl_py-0.13.0-py3-none-any.whl (132 kB)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\9415\anaconda3\lib\site-packages (from tensorflow) (3.7.4.3)
# Collecting gast==0.4.0
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Requirement already satisfied: six~=1.15.0 in c:\users\9415\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Collecting grpcio~=1.34.0
#   Downloading grpcio-1.34.1-cp38-cp38-win_amd64.whl (2.9 MB)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.33.0-py2.py3-none-any.whl (151 kB)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\9415\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (1.0.1)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
#
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.4-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\9415\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (50.3.1.post20201107)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\9415\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (2.24.0)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\9415\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\9415\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\9415\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\9415\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (3.0.4)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Building wheels for collected packages: termcolor, wrapt
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4835 sha256=e9ba7ecd281d336fc637becebda21bab18e87a9aa76a34aec1485f9256ca2cd3
#   Stored in directory: c:\users\9415\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-py3-none-any.whl size=19558 sha256=20f73ae99ce25c099ca9993781c1dcd068a19e1b6f029f7bf8a38bf7f404d233
#   Stored in directory: c:\users\9415\appdata\local\pip\cache\wheels\5f\fd\9e\b6cf5890494cb8ef0b5eaff72e5d55a70fb56316007d6dfe73
# Successfully built termcolor wrapt
# Installing collected packages: termcolor, cachetools, pyasn1, pyasn1-modules, rsa, google-auth, markdown, tensorboard-plugin-wit, protobuf, absl-py, oauthlib, requests-oauthlib, google-auth-oauthlib, grpcio, tensorboard-data-server, tensorboard, h5py, keras-nightly, flatbuffers, astunparse, keras-preprocessing, tensorflow-estimator, opt-einsum, google-pasta, gast, wrapt, tensorflow
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.11.2
#     Uninstalling wrapt-1.11.2:
#       Successfully uninstalled wrapt-1.11.2
# Successfully installed absl-py-0.13.0 astunparse-1.6.3 cachetools-4.2.2 flatbuffers-1.12 gast-0.4.0 google-auth-1.33.0 google-auth-oauthlib-0.4.4 google-pasta-0.2.0 grpcio-1.34.1 h5py-3.1.0 keras-nightly-2.5.0.dev2021032900 keras-preprocessing-1.1.2 markdown-3.3.4 oauthlib-3.1.1 opt-einsum-3.3.0 protobuf-3.17.3 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.7.2 tensorboard-2.5.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.5.0 tensorflow-estimator-2.5.0 termcolor-1.1.0 wrapt-1.12.1

# %%
pip install cvlib
# Out:
# Collecting cvlib
#   Downloading cvlib-0.2.6.tar.gz (10.0 MB)
# Requirement already satisfied: numpy in c:\users\9415\anaconda3\lib\site-packages (from cvlib) (1.19.2)
# Collecting progressbar
#   Downloading progressbar-2.5.tar.gz (10 kB)
# Requirement already satisfied: requests in c:\users\9415\anaconda3\lib\site-packages (from cvlib) (2.24.0)
# Requirement already satisfied: pillow in c:\users\9415\anaconda3\lib\site-packages (from cvlib) (8.0.1)
# Requirement already satisfied: imageio in c:\users\9415\anaconda3\lib\site-packages (from cvlib) (2.9.0)
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\9415\anaconda3\lib\site-packages (from requests->cvlib) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\9415\anaconda3\lib\site-packages (from requests->cvlib) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\9415\anaconda3\lib\site-packages (from requests->cvlib) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\9415\anaconda3\lib\site-packages (from requests->cvlib) (1.25.11)
# Building wheels for collected packages: cvlib, progressbar, imutils
#   Building wheel for cvlib (setup.py): started
#   Building wheel for cvlib (setup.py): finished with status 'done'
#   Created wheel for cvlib: filename=cvlib-0.2.6-py3-none-any.whl size=10044628 sha256=27198984f00f55a67ede9c5ce25a5887567a80f170cdc9d4be0e209fb24f7260
#   Stored in directory: c:\users\9415\appdata\local\pip\cache\wheels\ab\cb\f5\2d027cae91342418d4a84c6955d080c2e361b60bb72db3f71c
#   Building wheel for progressbar (setup.py): started
#   Building wheel for progressbar (setup.py): finished with status 'done'
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12078 sha256=9c28697a7df0cbcd4609984fd62a618876024029b89316db856f6b4da24dabc7
#   Stored in directory: c:\users\9415\appdata\local\pip\cache\wheels\2c\67\ed\d84123843c937d7e7f5ba88a270d11036473144143355e2747
#   Building wheel for imutils (setup.py): started
#   Building wheel for imutils (setup.py): finished with status 'done'
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25862 sha256=518f34eda7bbc470a413b36134579568f7701d0fd95c2f1cc5619894906696e7
#   Stored in directory: c:\users\9415\appdata\local\pip\cache\wheels\59\1b\52\0dea905f8278d5514dc4d0be5e251967f8681670cadd3dca89
# Successfully built cvlib progressbar imutils
# Installing collected packages: progressbar, imutils, cvlib
# Successfully installed cvlib-0.2.6 imutils-0.5.4 progressbar-2.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import cvlib as cv

# %%
from cvlib.object_detection import draw_bbox

# %%
im = cv2.imread('cars_img.jpg')

# %%
bbox, label, conf = cv.detect_common_objects(im)
# Out:
# Downloading yolov4.cfg from https://raw.githubusercontent.com/AlexeyAB/darknet/master/cfg/yolov4.cfg
#   0% |                                                                        |
# Downloading yolov4.weights from https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights
#  99% |####################################################################### |
# Downloading yolov3_classes.txt from https://github.com/arunponnusamy/object-detection-opencv/raw/master/yolov3.txt
# 100% |                                                                        |

# %%
output_image = draw_bbox(im,bbox,label,conf)

# %%
plt.imshow(output_image)

# %%
plt.show()

# %%
print("Number of cars in the Image is : "+str(label.count('car')))
# Out:
# Number of cars in the Image is : 18

# %% [markdown]
# 2nd Image demo

# %%
im1 = cv2.imread('cars_img1.jpg')

# %%
bbox, label, conf = cv.detect_common_objects(im1)

# %%
output_image1 = draw_bbox(im1,bbox,label,conf)

# %%
plt.imshow(output_image1)

# %%
print("Number of cars in the Image is : "+str(label.count('car')))
# Out:
# Number of cars in the Image is : 7
